# %% [markdown]
# <a href="https://colab.research.google.com/github/josoberrio/Entrega-trabajo-goolge-colab/blob/main/Ejercicio_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ejercicio 17
import math
# input pedir datos al usuario

radio = float(input("Ingrese el radio del círculo: "))

# math es uba funcion que sirve para cuando necesitas hacer calculos

area = math.pi * radio**2
longitud = 2 * math.pi * radio
#** sirve para elevarlo  potencia }

print("El área es:", area)
print("La longitud de la circunferencia es:", longitud)
# Out:
# Ingrese el radio del círculo: 2
# El área es: 12.566370614359172
# La longitud de la circunferencia es: 12.566370614359172
