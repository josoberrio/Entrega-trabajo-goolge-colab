# %% [markdown]
# <a href="https://colab.research.google.com/github/josoberrio/Entrega-trabajo-goolge-colab/blob/main/Ejercicio14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ejercicio 14.  Elabore un algoritmo que lea un número y obtenga su cuadrado y su cubo.
numero = float(input("Ingrese un número: "))
# Calcular cuadrado y cubo
cuadrado = numero ** 2
cubo = numero ** 3
# Mostrar resultados
print("El cuadrado es:", cuadrado)
print("El cubo es:", cubo)
# Out:
# Ingrese un número: 12
# El cuadrado es: 144.0
# El cubo es: 1728.0
